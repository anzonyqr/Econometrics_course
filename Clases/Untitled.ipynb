# %% [markdown]
# # Random Variables
#
# Toma valores numericos y arroja un resultado detrminado por un experimento.

# %%
d = { (i, j): i + j for i in range( 1 , 7 ) for j in range( 1, 7 ) }

# %%
from collections import defaultdict

# %%
dinv = defaultdict( list )

# %%
for i, j in d.items():
    dinv[ j ].append( i )

# %%
X = { i : len( j ) / 36.0 for i, j in dinv.items() }

# %%
X
# Out:
# {2: 0.027777777777777776,
#  3: 0.05555555555555555,
#  4: 0.08333333333333333,
#  5: 0.1111111111111111,
#  6: 0.1388888888888889,
#  7: 0.16666666666666666,
#  8: 0.1388888888888889,
#  9: 0.1111111111111111,
#  10: 0.08333333333333333,
#  11: 0.05555555555555555,
#  12: 0.027777777777777776}

# %%
d1 = { (i,j,k):((i*j*k)/2>i+j+k) for i in range(1,7) for j in range(1,7) for k in range(1,7) }

# %%
dinv1 = defaultdict( list )

# %%
for i, j in d1.items():
    dinv1[ j ].append( i )

# %%
dinv1
# Out:
# defaultdict(list,
#             {False: [(1, 1, 1),
#               (1, 1, 2),
#               (1, 1, 3),
#               (1, 1, 4),
#               (1, 1, 5),
#               (1, 1, 6),
#               (1, 2, 1),
#               (1, 2, 2),
#               (1, 2, 3),
#               (1, 2, 4),
#               (1, 2, 5),
#               (1, 2, 6),
#               (1, 3, 1),
#               (1, 3, 2),
#               (1, 3, 3),
#               (1, 3, 4),
#               (1, 3, 5),
#               (1, 3, 6),
#               (1, 4, 1),
#               (1, 4, 2),
#               (1, 4, 3),
#               (1, 4, 4),
#               (1, 4, 5),
#               (1, 5, 1),
#               (1, 5, 2),
#               (1, 5, 3),
#               (1, 5, 4),
#               (1, 6, 1),
#               (1, 6, 2),
#               (1, 6, 3),
#               (2, 1, 1),
#               (2, 1, 2),
#               (2, 1, 3),
#               (2, 1, 4),
#               (2, 1, 5),
#               (2, 1, 6),
# ...
